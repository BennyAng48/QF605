# %% [markdown]
# # Convexity Correction

# %% [markdown]
# # 👉 <a id = "top">Table of Contents</a> 👈

# %% [markdown]
# # [1. Functions](#p1)
#
# # [2. CMS 10y semi-annually over the next 5 years](#p2)
#
# # [3. CMS 2y quarterly over the next 10 years](#p3)
#
# # [4. Comparing forward swap rates with the CMS rate](#p4)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from scipy.integrate import quad
from scipy.stats import norm

# %% [markdown]
# # <a id = "p1">1.</a>  <font color = "green"> Functions </font>  [back to table of contents](#top)

# %%
def g_0(K):
    return K

def g_1(K):
    return 1.0

def g_2(K):
    return 0.0

# %% [markdown]
# ### IRR and its derivatives
#
# The **Instantaneous Annuity Factor** and its first two derivatives with respect to strike \( K \) are given by:
#
# #### IRR(K)
#
# $$
# \text{IRR}(K) = \frac{1}{K} \left(1 - \frac{1}{\left(1 + \frac{K}{m}\right)^{m \cdot \text{tenor}}} \right)
# $$
#
# #### IRR′(K)
#
# $$
# \text{IRR}'(K) = -\frac{1}{K} \cdot \text{IRR}(K) + \frac{1}{K \cdot m} \cdot \frac{m \cdot \text{tenor}}{\left(1 + \frac{K}{m} \right)^{m \cdot \text{tenor} + 1}}
# $$
#
# #### IRR″(K)
#
# $$
# \text{IRR}''(K) = -\frac{2}{K} \cdot \text{IRR}'(K) - \frac{1}{K \cdot m^2} \cdot \frac{m \cdot \text{tenor} \cdot (m \cdot \text{tenor} + 1)}{\left(1 + \frac{K}{m} \right)^{m \cdot \text{tenor} + 2}}
# $$

# %%
def IRR_0(K, m, tenor):
    # Implementation of IRR(K) function
    value = 1/K * ( 1.0 - 1/(1 + K/m)**(tenor*m) )
    return value

def IRR_1(K, m, tenor):
    # Implementation of IRR'(K) function (1st derivative)
    firstDerivative = -1/K*IRR_0(K, m, tenor) + 1/(K*m)*tenor*m/(1+K/m)**(tenor*m+1)
    return firstDerivative

def IRR_2(K, m, tenor):
    # Implementation of IRR''(K) function (2nd derivative)
    secondDerivative = -2/K*IRR_1(K, m, tenor) - 1/(K*m*m)*(tenor*m)*(tenor*m+1)/(1+K/m)**(tenor*m+2)
    return secondDerivative

# %% [markdown]
# ### Convexity-Adjusted Function \( h(K) \) and its Derivatives
#
# Let \( h(K) = \frac{g(K)}{\text{IRR}(K)} \), where \( g(K) = K \).
# Then the first and second derivatives of \( h(K) \) are:
#
# #### \( h(K) \)
#
# $$
# h(K) = \frac{g_0(K)}{\text{IRR}(K)} = \frac{K}{\text{IRR}(K)}
# $$
#
# #### \( h'(K) \)
#
# $$
# h'(K) = \frac{\text{IRR}(K) \cdot g_1(K) - g_0(K) \cdot \text{IRR}'(K)}{\text{IRR}(K)^2}
# $$
#
# #### \( h''(K) \)
#
# $$
# h''(K) = \frac{g_2(K) \cdot \text{IRR}(K) - g_0(K) \cdot \text{IRR}''(K) - 2 \cdot g_1(K) \cdot \text{IRR}'(K)}{\text{IRR}(K)^2}
# + \frac{2 \cdot g_0(K) \cdot \left(\text{IRR}'(K)\right)^2}{\text{IRR}(K)^3}
# $$

# %%
def h_0(K, m, tenor):
    # implementation of h(K)
    value = g_0(K) / IRR_0(K, m, tenor)
    return value

def h_1(K, m, tenor):
    # implementation of h'(K) (1st derivative)
    firstDerivative = (IRR_0(K, m, tenor)*g_1(K) - g_0(K)*IRR_1(K, m, tenor)) / IRR_0(K, m, tenor)**2
    return firstDerivative

def h_2(K, m, tenor):
    # implementation of h''(K) (2nd derivative)
    secondDerivative = ((IRR_0(K, m, tenor)*g_2(K) - IRR_2(K, m, tenor)*g_0(K) - 2.0*IRR_1(K, m, tenor)*g_1(K))/IRR_0(K, m, tenor)**2 
                        + 2.0*IRR_1(K, m, tenor)**2*g_0(K)/IRR_0(K, m, tenor)**3)
    return secondDerivative

# %%
## Import IRS Data
Discount_Factors = pd.read_csv("Discount_Factors.csv")
Discount_Factors
# Out:
#     Years      Rate  OIS_Discount_Factor  IRS_Discount_Factor  Forward_LIBOR
# 0     0.5  0.025000             0.998752             0.987654       0.025000
# 1     1.0  0.028000             0.997009             0.972577       0.031245
# 2     1.5  0.029000             0.995270             0.957378       0.031242
# 3     2.0  0.030000             0.993531             0.942179       0.033275
# 4     2.5  0.030750             0.991773             0.926330       0.034038
# 5     3.0  0.031500             0.990015             0.910482       0.035565
# 6     3.5  0.032000             0.988066             0.894731       0.035309
# 7     4.0  0.032500             0.986117             0.878981       0.036328
# 8     4.5  0.032750             0.984150             0.863985       0.035053
# 9     5.0  0.033000             0.982184             0.848989       0.035562
# 10    5.5  0.033500             0.979740             0.832796       0.038877
# 11    6.0  0.034000             0.977295             0.816603       0.039898
# 12    6.5  0.034500             0.974850             0.800409       0.040920
# 13    7.0  0.035000             0.972406             0.784216       0.041942
# 14    7.5  0.035333             0.969668             0.768965       0.040406
# 15    8.0  0.035667             0.966929             0.753714       0.041087
# 16    8.5  0.036000             0.964191             0.738463       0.041768
# 17    9.0  0.036333             0.961453             0.723212       0.042450
# 18    9.5  0.036667             0.958715             0.707961       0.043131
# 19   10.0  0.037000             0.955977             0.692710       0.043813
# 20   10.5  0.037300             0.953140             0.678547       0.043778
# 21   11.0  0.037600             0.950304             0.664384       0.044392
# 22   11.5  0.037900             0.947467             0.650221       0.045006
# 23   12.0  0.038200             0.944631             0.636058       0.045621
# 24   12.5  0.038500             0.941794             0.621896       0.046236
# 25   13.0  0.038800             0.938958             0.607733       0.046851
# 26   13.5  0.039100             0.936121             0.593570       0.047466
# 27   14.0  0.039400             0.933285             0.579407       0.048081
# 28   14.5  0.039700             0.930448             0.565244       0.048697
# 29   15.0  0.040000             0.927611             0.551081       0.049313
# 30   15.5  0.040500             0.924858             0.536794       0.056329
# 31   16.0  0.041000             0.922104             0.522508       0.057361
# 32   16.5  0.041500             0.919351             0.508222       0.058393
# 33   17.0  0.042000             0.916597             0.493935       0.059426
# 34   17.5  0.042500             0.913844             0.479649       0.060460
# 35   18.0  0.043000             0.911090             0.465363       0.061495
# 36   18.5  0.043500             0.908337             0.451077       0.062530
# 37   19.0  0.044000             0.905583             0.436790       0.063566
# 38   19.5  0.044500             0.902829             0.422504       0.064602
# 39   20.0  0.045000             0.900076             0.408218       0.065639
# 40   20.5  0.045250             0.897442             0.398990       0.056039
# 41   21.0  0.045500             0.894809             0.389762       0.056554
# 42   21.5  0.045750             0.892176             0.380534       0.057069
# 43   22.0  0.046000             0.889542             0.371307       0.057585
# 44   22.5  0.046250             0.886909             0.362079       0.058101
# 45   23.0  0.046500             0.884275             0.352851       0.058616
# 46   23.5  0.046750             0.881642             0.343623       0.059132
# 47   24.0  0.047000             0.879008             0.334396       0.059648
# 48   24.5  0.047250             0.876375             0.325168       0.060165
# 49   25.0  0.047500             0.873741             0.315940       0.060681
# 50   25.5  0.047750             0.871108             0.306712       0.061198
# 51   26.0  0.048000             0.868474             0.297484       0.061714
# 52   26.5  0.048250             0.865841             0.288257       0.062231
# 53   27.0  0.048500             0.863207             0.279029       0.062748
# 54   27.5  0.048750             0.860574             0.269801       0.063266
# 55   28.0  0.049000             0.857941             0.260573       0.063783
# 56   28.5  0.049250             0.855307             0.251346       0.064300
# 57   29.0  0.049500             0.852674             0.242118       0.064818
# 58   29.5  0.049750             0.850040             0.232890       0.065336
# 59   30.0  0.050000             0.847407             0.223662       0.065854

# %%
## Import the SABR parameters in Part 2
Calibration_parameters_df = pd.read_csv('Calibration_parameters_df.csv')
Calibration_parameters_df
# Out:
#     start  tenor          Beta     alpha       rho        nu   sigma
# 0       1      1  1.638113e-10  0.139074 -0.633223  2.049416  0.2250
# 1       1      2  9.815395e-08  0.184650 -0.525114  1.677383  0.2872
# 2       1      3  5.731735e-07  0.196851 -0.482848  1.438125  0.2978
# 3       1      5  9.601260e-07  0.178059 -0.414493  1.064842  0.2607
# 4       1     10  2.384479e-04  0.169984 -0.255690  0.792209  0.2447
# 5       5      1  2.484133e-07  0.166618 -0.585668  1.340427  0.2726
# 6       5      2  1.765342e-08  0.199534 -0.547030  1.062005  0.2983
# 7       5      3  4.283785e-06  0.210314 -0.549687  0.936773  0.2998
# 8       5      5  7.319718e-06  0.190244 -0.506814  0.674546  0.2660
# 9       5     10  1.081065e-01  0.174809 -0.415705  0.511310  0.2451
# 10     10      1  6.907810e-07  0.178282 -0.548440  1.010303  0.2854
# 11     10      2  4.400782e-07  0.196313 -0.547530  0.928630  0.2928
# 12     10      3  1.868118e-05  0.208253 -0.553589  0.871684  0.2940
# 13     10      5  2.223913e-06  0.201583 -0.563656  0.722512  0.2674
# 14     10     10  6.459046e-04  0.180231 -0.508403  0.580357  0.2437

# %%
Alpha = Calibration_parameters_df[["start","tenor","alpha"]]
Alpha = Alpha.pivot(index="start",columns="tenor",values="alpha")
Alpha
# Out:
# tenor        1         2         3         5         10
# start
# 1      0.139074  0.184650  0.196851  0.178059  0.169984
# 5      0.166618  0.199534  0.210314  0.190244  0.174809
# 10     0.178282  0.196313  0.208253  0.201583  0.180231

# %%
Rho = Calibration_parameters_df[["start","tenor","rho"]]
Rho = Rho.pivot(index="start",columns="tenor",values="rho")
Rho
# Out:
# tenor        1         2         3         5         10
# start
# 1     -0.633223 -0.525114 -0.482848 -0.414493 -0.255690
# 5     -0.585668 -0.547030 -0.549687 -0.506814 -0.415705
# 10    -0.548440 -0.547530 -0.553589 -0.563656 -0.508403

# %%
Nu = Calibration_parameters_df[["start","tenor","nu"]]
Nu = Nu.pivot(index="start",columns="tenor",values="nu")
Nu
# Out:
# tenor        1         2         3         5         10
# start
# 1      2.049416  1.677383  1.438125  1.064842  0.792209
# 5      1.340427  1.062005  0.936773  0.674546  0.511310
# 10     1.010303  0.928630  0.871684  0.722512  0.580357

# %%
## Linear interpolate Libor DF
def LIBORDF(T, 
            df = Discount_Factors):
    x = list(df['Years'])
    y = list(df['IRS_Discount_Factor'])
    return np.interp(T, x, y)

## Linear interpolate OIS DF
def OISDF(T, 
          df = Discount_Factors):
    x = list(df['Years'])
    y = list(df['OIS_Discount_Factor'])
    return np.interp(T, x, y)

def Forward_LIBOR(m, 
                  D1, 
                  D2):
    return m * ((D1 - D2) / D2)

# %%
## Calculate swap rate
def Forward_Swap_Rate(expiry, 
                      tenor, 
                      m):
    """
    Computes the forward par swap rate starting at `expiry`, with `tenor` years,
    and `m` fixed payments per year (e.g., 2 for semiannual).
    """
    floated, fix = 0, 0
    for i in range(1, int(tenor * m)+1):
        end = expiry + i/m
        floated += OISDF(end) * Forward_LIBOR(m, LIBORDF(end-1/m), LIBORDF(end)) * 1/m
        fix += OISDF(expiry + i/m)/m
    return floated/fix

# %%
## Calculate the SABR implied volatitlity
def SABR(F, 
         K, 
         T, 
         alpha, 
         beta, 
         rho, 
         nu):
    
    """
    Compute the SABR implied volatility.

    Parameters:
    F: Forward price
    K: Strike price
    T: Time to maturity
    alpha: Volatility of the underlying asset
    beta: SABR exponent
    rho: Correlation between the asset price and its volatility
    nu: Volatility of volatility

    Returns:
    sabrsigma: SABR implied volatility
    """
    
    X = K
    if F == K:
        numer1 = (((1 - beta)**2)/24)*alpha*alpha/(F**(2 - 2*beta))
        numer2 = 0.25*rho*beta*nu*alpha/(F**(1 - beta))
        numer3 = ((2 - 3*rho*rho)/24)*nu*nu
        VolAtm = alpha*(1 + (numer1 + numer2 + numer3)*T)/(F**(1-beta))
        sabrsigma = VolAtm
    else:
        z = (nu/alpha)*((F*X)**(0.5*(1-beta)))*np.log(F/X)
        zhi = np.log((((1 - 2*rho*z + z*z)**0.5) + z - rho)/(1 - rho))
        numer1 = (((1 - beta)**2)/24)*((alpha*alpha)/((F*X)**(1 - beta)))
        numer2 = 0.25*rho*beta*nu*alpha/((F*X)**((1 - beta)/2))
        numer3 = ((2 - 3*rho*rho)/24)*nu*nu
        numer = alpha*(1 + (numer1 + numer2 + numer3)*T)*z
        denom1 = ((1 - beta)**2/24)*(np.log(F/X))**2
        denom2 = (((1 - beta)**4)/1920)*((np.log(F/X))**4)
        denom = ((F*X)**((1 - beta)/2))*(1 + denom1 + denom2)*zhi
        sabrsigma = numer/denom
        
    return sabrsigma

# %%
# Linear interpolate SABR parameters
def ParameterInterp (dataframe, 
                     tenor, 
                     expiry):
    
    """
    Linearly interpolate SABR model parameters based on tenor and expiry.

    Args:
    dataframe: DataFrame containing SABR parameters for different tenors
    tenor: The tenor to interpolate (e.g., 2, 3, 5, 10)
    expiry: The expiry to interpolate (e.g., 1, 2, 5, 10)

    Returns:
    Interpolated value of SABR parameter for the given tenor and expiry.
    """
    
    # Step 1: Interpolate parameters for the given tenor across the known tenors [1, 5, 10]
    linear_interp = []
    new_paras = []
    
    for i in [1,2,3,5,10]:      # These represent the available tenors
        linear_interp.append(np.interp(tenor, [1, 5, 10], dataframe[i]))
    
    for i in range(5):
        new_paras.append(linear_interp[i])
    
    # Step 2: Interpolate the results for the given expiry
    result = np.interp(expiry, [1, 2, 3, 5, 10], new_paras)
    
    return float(result)

# %%
## Black 76 pricing formula
def black76_payer(F, K, t, sigma):
    d1 = (np.log(F/K)+(1/2)*(sigma**2)*t)/(sigma*np.sqrt(t))
    d2 = d1 - sigma * np.sqrt(t)
    price = F*norm.cdf(d1) - K*norm.cdf(d2)
    return price

def black76_receiver(F, K, t, sigma):
    d1 = (np.log(F/K)+1/2*(sigma**2)*t)/(sigma*np.sqrt(t))
    d2 = d1 - sigma * np.sqrt(t)
    price = K*norm.cdf(-d2) - F*norm.cdf(-d1)
    return price

# %%
## IRR-Settled payer and recevier swaption integrant at time T
def Rec_Integral(F, K, m, tenor, t, sigma):
    """
    Calculates the integral for the receiver swaption at time T.
    
    Parameters:
    F (float): Forward price.
    K (float): Strike price.
    m (int): Frequency of payments.
    tenor (float): The tenor of the swap (e.g., 5 years).
    t (float): Time to maturity (in years).
    sigma (float): Volatility of the underlying swaption.
    
    Returns:
    float: The receiver swaption integral value.
    """
    return h_2(K, m, tenor) * black76_receiver(F, K, t, sigma)

def Pay_Integral(F, K, m, tenor, t, sigma):
    """
    Calculates the integral for the payer swaption at time T.
    
    Parameters:
    F (float): Forward price.
    K (float): Strike price.
    m (int): Frequency of payments.
    tenor (float): The tenor of the swap (e.g., 5 years).
    t (float): Time to maturity (in years).
    sigma (float): Volatility of the underlying swaption.
    
    Returns:
    float: The payer swaption integral value.
    """
    return h_2(K, m, tenor) * black76_payer(F, K, t, sigma)

# %%
## Calculate the CMS rate
def CMS(m, tenor, expiry):
    """
    Calculate the CMS rate based on the forward swap rate, 
    and integrals of receiver and payer swaption prices.

    Parameters:
    m (int): Payment frequency (e.g., semi-annual).
    tenor (float): The tenor of the swap (e.g., 5 years).
    expiry (float): Time to maturity (e.g., 1 year).
    
    Returns:
    float: The CMS rate.
    """
    
    # Get forward swap rate F
    F = Forward_Swap_Rate(expiry, tenor, m)
    
    # print(f"Forward Swap Rate is {F}")
    # Interpolate the SABR parameters: alpha, rho, and nu
    alpha = ParameterInterp(Alpha, tenor, expiry)
    rho = ParameterInterp(Rho, tenor ,expiry)
    nu = ParameterInterp(Nu, tenor ,expiry)
    
    Discount_factor = (OISDF(expiry))
    # Integrate over the receiver swaption strike range (0 to F) and payer swaption strike range (F to 0.1)
    CMS = \
            (
                Discount_factor*F 
                + quad(lambda x: Rec_Integral(F, x, m, tenor ,expiry, SABR(F,x,expiry,alpha,0.9,rho,nu)), 0, F)[0]
                + quad(lambda x: Pay_Integral(F, x, m, tenor ,expiry, SABR(F,x,expiry,alpha,0.9,rho,nu)), F, 0.1)[0]  # The upper range of integration is 0.2
                )
            
    return CMS

# %%
## Calculate the present value of the CMS leg
def PV_CMS(m, tenor, expiry):
    n = int(expiry*m)           # Number of coupon payments
    pv = 0
    for i in range(1,n+1):      # For each coupon payment
        ti = i/m                # Get the time (in years) it is supposed to be paid out
        pv += (OISDF(ti)/m) * CMS(m, tenor, expiry)     # Calculate its present value by discounting by OIS discount factor
    return pv

# %% [markdown]
# # <a id = "p2">2.</a>  <font color = "green"> CMS 10y semi-annually over the next 5 years </font>  [back to table of contents](#top)

# %%
tenor = 10
expiry = 5
m = 2
print('PV of a leg receiving CMS10y semi-annually over the next 5 years is ', PV_CMS(m, tenor, expiry))
# Out:
# PV of a leg receiving CMS10y semi-annually over the next 5 years is  0.21486514715796207

# %% [markdown]
# # <a id = "p3">3.</a>  <font color = "green"> CMS 2y quarterly over the next 10 years </font>  [back to table of contents](#top)

# %%
tenor1 = 2
expiry1 = 10
m1 = 4
print('PV of a leg receiving CMS2y quarterly over the next 10 years = ', PV_CMS(m1, tenor1, expiry1))
# Out:
# PV of a leg receiving CMS2y quarterly over the next 10 years =  0.41327815608237956

# %% [markdown]
# # <a id = "p4">4.</a>  <font color = "green"> Comparing forward swap rates with the CMS rate </font>  [back to table of contents](#top)

# %%
forward_swap_rates = pd.read_csv("Forward_swap_rates_df.csv")   # From Part 1
forward_swap_rates
# Out:
#     Start  Tenor  Forward_Swap_Rates
# 0       1      1            0.032007
# 1       1      2            0.033259
# 2       1      3            0.034011
# 3       1      5            0.035255
# 4       1     10            0.038428
# 5       5      1            0.039274
# 6       5      2            0.040075
# 7       5      3            0.040072
# 8       5      5            0.041093
# 9       5     10            0.043634
# 10     10      1            0.042189
# 11     10      2            0.043116
# 12     10      3            0.044097
# 13     10      5            0.046249
# 14     10     10            0.053458

# %%
cms_start_time = [1, 5, 10]
cms_duration = [1, 2, 3, 5, 10]
cms_forward_swap = [[x, y] for x in cms_start_time for y in cms_duration]
cms_forward_swap
# Out:
# [[1, 1],
#  [1, 2],
#  [1, 3],
#  [1, 5],
#  [1, 10],
#  [5, 1],
#  [5, 2],
#  [5, 3],
#  [5, 5],
#  [5, 10],
#  [10, 1],
#  [10, 2],
#  [10, 3],
#  [10, 5],
#  [10, 10]]

# %%
cms_rates = []
for forward_swap in cms_forward_swap:
    expiry, tenor = forward_swap
    discount_factor = Discount_Factors.loc[tenor, "OIS_Discount_Factor"]
    swap_rate = CMS(m = 2, 
                    tenor = tenor, 
                    expiry = expiry)
    
    cms_rates.append([expiry, tenor, swap_rate])

cms_rates_df = pd.DataFrame(
    cms_rates,
    columns=[
        "Expiry",
        "Tenor",
        "CMS Rate",
    ],
)

# %%
cms_rates_df
# Out:
#     Expiry  Tenor  CMS Rate
# 0        1      1  0.032024
# 1        1      2  0.033250
# 2        1      3  0.033988
# 3        1      5  0.035217
# 4        1     10  0.038385
# 5        5      1  0.039517
# 6        5      2  0.040057
# 7        5      3  0.039926
# 8        5      5  0.040802
# 9        5     10  0.043377
# 10      10      1  0.042083
# 11      10      2  0.042521
# 12      10      3  0.043245
# 13      10      5  0.045068
# 14      10     10  0.052173

# %%
forward_swap
# Out:
# [10, 10]

# %%
plt.plot(cms_rates_df["Tenor"][0:5],forward_swap_rates["Forward_Swap_Rates"][0:5],label='1y Expiry FSR')
plt.plot(cms_rates_df["Tenor"][0:5],cms_rates_df["CMS Rate"][0:5],label='1y Expiry CMS')
plt.xlabel('Tenor')
plt.ylabel('Rates')
plt.title('Forward Swap Rates vs CMS Rates - 1y Expiry')
plt.legend()
plt.show()

# %%
plt.plot(cms_rates_df["Tenor"][5:10],forward_swap_rates["Forward_Swap_Rates"][5:10],label='5y Expiry FSR')
plt.plot(cms_rates_df["Tenor"][5:10],cms_rates_df["CMS Rate"][5:10],label='5y Expiry CMS')
plt.xlabel('Tenor')
plt.ylabel('Rates')
plt.title('Forward Swap Rates vs CMS Rates - 5y Expiry')
plt.legend()
plt.show()

# %%
plt.plot(cms_rates_df["Tenor"][5:10],forward_swap_rates["Forward_Swap_Rates"][10:15],label='10y Expiry FSR')
plt.plot(cms_rates_df["Tenor"][5:10],cms_rates_df["CMS Rate"][10:15],label='10y Expiry CMS')
plt.xlabel('Tenor')
plt.ylabel('Rates')
plt.title('Forward Swap Rates vs CMS Rates - 10y Expiry')
plt.legend()
plt.show()
